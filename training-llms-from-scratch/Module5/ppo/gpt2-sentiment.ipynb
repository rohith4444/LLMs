# %% [markdown]
# # Tune GPT2 to generate positive reviews
# > Optimise GPT2 to produce positive IMDB movie reviews using a BERT sentiment classifier as a reward function.

# %% [markdown]
# <div style="text-align: center">
# <img src='https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/gpt2_bert_training.png' width='600'>
# <p style="text-align: center;"> <b>Figure:</b> Experiment setup to tune GPT2. The yellow arrows are outside the scope of this notebook, but the trained models are available through Hugging Face. </p>
# </div>
#
#
# In this notebook we fine-tune GPT2 (small) to generate positive movie reviews based on the IMDB dataset. The model gets the start of a real review and is tasked to produce positive continuations. To reward positive continuations we use a BERT classifier to analyse the sentiment of the produced sentences and use the classifier's outputs as rewards signals for PPO training.

# %% [markdown]
# ## Setup experiment

# %% [markdown]
# ### Import dependencies

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install transformers trl wandb
# Out:
# Requirement already satisfied: transformers in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (4.37.0)
# Requirement already satisfied: trl in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (0.7.5.dev0)
# Requirement already satisfied: wandb in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: filelock in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: torch>=1.4.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from trl) (2.1.2)
# Requirement already satisfied: accelerate in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from trl) (0.26.1)
# Requirement already satisfied: datasets in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from trl) (2.15.0)
# Requirement already satisfied: tyro>=0.5.11 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from trl) (0.5.14)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from wandb) (7.1.2)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from wandb) (3.1.40)
# Requirement already satisfied: psutil>=5.0.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from wandb) (5.9.6)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from wandb) (1.37.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: setproctitle in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from wandb) (69.0.2)
# Requirement already satisfied: appdirs>=1.4.3 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from wandb) (3.20.2)
# Requirement already satisfied: six>=1.4.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: fsspec>=2023.5.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: sympy in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (1.11.1)
# Requirement already satisfied: networkx in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.1)
# Requirement already satisfied: jinja2 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from torch>=1.4.0->trl) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl) (12.3.52)
# Requirement already satisfied: docstring-parser>=0.14.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (0.15)
# Requirement already satisfied: rich>=11.1.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (13.6.0)
# Requirement already satisfied: shtab>=1.5.6 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (1.6.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from datasets->trl) (14.0.1)
# Requirement already satisfied: pyarrow-hotfix in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from datasets->trl) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from datasets->trl) (0.3.7)
# Requirement already satisfied: pandas in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from datasets->trl) (2.1.3)
# Requirement already satisfied: xxhash in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from datasets->trl) (3.4.1)
# Requirement already satisfied: multiprocess in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from datasets->trl) (0.70.15)
# Requirement already satisfied: aiohttp in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from datasets->trl) (3.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from aiohttp->datasets->trl) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from aiohttp->datasets->trl) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from pandas->datasets->trl) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from pandas->datasets->trl) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from tqdm import tqdm
import pandas as pd

tqdm.pandas()

from transformers import pipeline, AutoTokenizer
from datasets import load_dataset

from trl import PPOTrainer, PPOConfig, AutoModelForCausalLMWithValueHead
from trl.core import LengthSampler
# Out:
# /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# 2024-01-27 15:05:59.199212: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-27 15:05:59.199257: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-27 15:05:59.200165: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-27 15:05:59.206345: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-27 15:05:59.975750: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2024-01-27 15:06:02,600] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)

# %% [markdown]
# ### Configuration

# %%
config = PPOConfig(
    model_name="lvwerra/gpt2-imdb",
    learning_rate=1.41e-5,
    log_with="wandb",
)

sent_kwargs = {"return_all_scores": True, "function_to_apply": "none", "batch_size": 16}

# %%
import wandb

wandb.init()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: smangrul. Use `wandb login --relogin` to force relogin
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/raid/sourab/trl/examples/notebooks/wandb/run-20240127_150604-dvzrkd3f</code>
# Syncing run <strong><a href='https://wandb.ai/smangrul/trl-examples_notebooks/runs/dvzrkd3f' target="_blank">curious-sound-1</a></strong> to <a href='https://wandb.ai/smangrul/trl-examples_notebooks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/smangrul/trl-examples_notebooks' target="_blank">https://wandb.ai/smangrul/trl-examples_notebooks</a>
#  View run at <a href='https://wandb.ai/smangrul/trl-examples_notebooks/runs/dvzrkd3f' target="_blank">https://wandb.ai/smangrul/trl-examples_notebooks/runs/dvzrkd3f</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/smangrul/trl-examples_notebooks/runs/dvzrkd3f?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# You can see that we load a GPT2 model called `gpt2_imdb`. This model was additionally fine-tuned on the IMDB dataset for 1 epoch with the huggingface [script](https://github.com/huggingface/transformers/blob/master/examples/run_language_modeling.py) (no special settings). The other parameters are mostly taken from the original paper ["Fine-Tuning Language Models from Human Preferences"](
# https://arxiv.org/pdf/1909.08593.pdf). This model as well as the BERT model is available in the Huggingface model zoo [here](https://huggingface.co/models). The following code should automatically download the models.

# %% [markdown]
# ## Load data and models

# %% [markdown]
# ### Load IMDB dataset
# The IMDB dataset contains 50k movie review annotated with "positive"/"negative" feedback indicating the sentiment.  We load the IMDB dataset into a DataFrame and filter for comments that are at least 200 characters. Then we tokenize each text and cut it to random size with the `LengthSampler`.

# %%
def build_dataset(config, dataset_name="imdb", input_min_text_length=2, input_max_text_length=8):
    """
    Build dataset for training. This builds the dataset from `load_dataset`, one should
    customize this function to train the model on its own dataset.

    Args:
        dataset_name (`str`):
            The name of the dataset to be loaded.

    Returns:
        dataloader (`torch.utils.data.DataLoader`):
            The dataloader for the dataset.
    """
    tokenizer = AutoTokenizer.from_pretrained(config.model_name)
    tokenizer.pad_token = tokenizer.eos_token
    # load imdb with datasets
    ds = load_dataset(dataset_name, split="train")
    ds = ds.rename_columns({"text": "review"})
    ds = ds.filter(lambda x: len(x["review"]) > 200, batched=False)

    input_size = LengthSampler(input_min_text_length, input_max_text_length)

    def tokenize(sample):
        sample["input_ids"] = tokenizer.encode(sample["review"])[: input_size()]
        sample["query"] = tokenizer.decode(sample["input_ids"])
        return sample

    ds = ds.map(tokenize, batched=False)
    ds.set_format(type="torch")
    return ds

# %%
dataset = build_dataset(config)


def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])
# Out:
# tokenizer_config.json:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/24895 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1168 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# ### Load pre-trained GPT2 language models

# %% [markdown]
# We load the GPT2 model with a value head and the tokenizer. We load the model twice; the first model is optimized while the second model serves as a reference to calculate the KL-divergence from the starting point. This serves as an additional reward signal in the PPO training to make sure the optimized model does not deviate too much from the original language model.

# %%
model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
ref_model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
tokenizer = AutoTokenizer.from_pretrained(config.model_name)

tokenizer.pad_token = tokenizer.eos_token
# Out:
# pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]
# /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %% [markdown]
# ### Initialize PPOTrainer
# The `PPOTrainer` takes care of device placement and optimization later on:

# %%
ppo_trainer = PPOTrainer(config, model, ref_model, tokenizer, dataset=dataset, data_collator=collator)
# Out:
# Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Finishing last run (ID:dvzrkd3f) before initializing another...
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.015 MB of 0.015 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">curious-sound-1</strong> at: <a href='https://wandb.ai/smangrul/trl-examples_notebooks/runs/dvzrkd3f' target="_blank">https://wandb.ai/smangrul/trl-examples_notebooks/runs/dvzrkd3f</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240127_150604-dvzrkd3f/logs</code>
# Successfully finished last run (ID:dvzrkd3f). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112168533468827, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/raid/sourab/trl/examples/notebooks/wandb/run-20240127_150638-qalt0gj8</code>
# Syncing run <strong><a href='https://wandb.ai/smangrul/trl/runs/qalt0gj8' target="_blank">royal-cherry-109</a></strong> to <a href='https://wandb.ai/smangrul/trl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/smangrul/trl' target="_blank">https://wandb.ai/smangrul/trl</a>
#  View run at <a href='https://wandb.ai/smangrul/trl/runs/qalt0gj8' target="_blank">https://wandb.ai/smangrul/trl/runs/qalt0gj8</a>

# %% [markdown]
# ### Load BERT classifier
# We load a BERT classifier fine-tuned on the IMDB dataset.

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"  # to avoid a `pipeline` bug
sentiment_pipe = pipeline("sentiment-analysis", model="lvwerra/distilbert-imdb", device=device)
# Out:
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# The model outputs are the logits for the negative and positive class. We will use the logits for positive class as a reward signal for the language model.

# %%
text = "this movie was really bad!!"
sentiment_pipe(text, **sent_kwargs)
# Out:
# /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# [[{'label': 'NEGATIVE', 'score': 2.3350484371185303},
#   {'label': 'POSITIVE', 'score': -2.726576328277588}]]

# %%
text = "this movie was really good!!"
sentiment_pipe(text, **sent_kwargs)
# Out:
# [[{'label': 'NEGATIVE', 'score': -2.294790267944336},
#   {'label': 'POSITIVE', 'score': 2.557040214538574}]]

# %% [markdown]
# ### Generation settings
# For the response generation we just use sampling and make sure top-k and nucleus sampling are turned off as well as a minimal length.

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %% [markdown]
# ## Optimize model

# %% [markdown]
# ### Training loop

# %% [markdown]
# The training loop consists of the following main steps:
# 1. Get the query responses from the policy network (GPT-2)
# 2. Get sentiments for query/responses from BERT
# 3. Optimize policy with PPO using the (query, response, reward) triplet
#
# **Training time**
#
# This step takes **~2h** on a V100 GPU with the above specified settings.

# %%
output_min_length = 4
output_max_length = 16
output_length_sampler = LengthSampler(output_min_length, output_max_length)


generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}


for epoch, batch in tqdm(enumerate(ppo_trainer.dataloader)):
    query_tensors = batch["input_ids"]

    #### Get response from gpt2
    response_tensors = []
    for query in query_tensors:
        gen_len = output_length_sampler()
        generation_kwargs["max_new_tokens"] = gen_len
        response = ppo_trainer.generate(query, **generation_kwargs)
        response_tensors.append(response.squeeze()[-gen_len:])
    batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]

    #### Compute sentiment score
    texts = [q + r for q, r in zip(batch["query"], batch["response"])]
    pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
    rewards = [torch.tensor(output[1]["score"]) for output in pipe_outputs]

    #### Run PPO step
    stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
    ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# 0it [00:00, ?it/s]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (32.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (27.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (24.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (42.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (41.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (30.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 1it [00:57, 57.48s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (82.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (2304.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (29.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (116.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (48.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (292.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (55.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (887.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (43.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (161.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (29.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (49.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (24.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (67.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (293.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (2697.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (41.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (965.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (52.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (41.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (69.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (49.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (22.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (125.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (31.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (5117.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (1018.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (293.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (50.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 2it [01:55, 57.58s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (51.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (27.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (123.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (58.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (153.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (27.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (51.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (44.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (27.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (46.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (144.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (54.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 3it [02:54, 58.58s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (115.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (27.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (77.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (29.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (29.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (31.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (24.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (26.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (39.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (39.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (25.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (26.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (27.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (84.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (26.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (25.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (24.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (25.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (115.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (27.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (79.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (26.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (26.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (24.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (115.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (34.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.08) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 4it [03:54, 58.81s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (82.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (77.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (363.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (44.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (556.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (42.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (304.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (82.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (63.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (557.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (62.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (341.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (41.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (84.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (552.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 5it [04:52, 58.82s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (34.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (55.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (31.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (269.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (776.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (68.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (34.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (58.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (673.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (37.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (58.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (28.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (33.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (739.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (678.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (58.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (167.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (69.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (32.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (45.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (33.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (22.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (34.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (60.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (39.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (46.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (157.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (29.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (769.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (59.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (25.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (689.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (63.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 6it [05:52, 59.13s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (30.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (29.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (45.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (64.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (736.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (52.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (28.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (30.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (44.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (733.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (67.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (22.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (43.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (30.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (41.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# ...
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (137.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (83.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (67.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (53.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (107.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (25.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (136.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (55.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (1344.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (65.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (65.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (37.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 92it [1:30:08, 58.55s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (39.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (41.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (136.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (35.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (42.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (98.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (237.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (127.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (36.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (253.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (99.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (49.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (42.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (88.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (38.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (42.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (37.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (48.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (253.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (130.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (43.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (40.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (101.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (89.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 93it [1:31:05, 58.35s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (1926.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (22.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (24.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (47.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (1703.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (53.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (33.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (56.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (1733.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (25.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 94it [1:32:05, 58.66s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (38.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (75.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (43.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (32.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (43.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (74.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (25.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (33.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (43.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (77.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (32.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 95it [1:33:05, 58.97s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (100.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (55.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (69.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (54.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (70.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (54.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (22.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 96it [1:34:04, 59.05s/it]/raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (53.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (51.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (219.44) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (38.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (51.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (222.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (51.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (54.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /raid/sourab/trl/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (222.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 97it [1:35:03, 58.80s/it]

# %% [markdown]
# ### Training progress
# If you are tracking the training progress with Weights&Biases you should see a plot similar to the one below. Check out the interactive sample report on wandb.ai: [link](https://app.wandb.ai/huggingface/trl-showcase/runs/1jtvxb1m/).
#
# <div style="text-align: center">
# <img src='https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/gpt2_tuning_progress.png' width='800'>
# <p style="text-align: center;"> <b>Figure:</b> Reward mean and distribution evolution during training. </p>
# </div>
#
# One can observe how the model starts to generate more positive outputs after a few optimisation steps.
#
# > Note: Investigating the KL-divergence will probably show that at this point the model has not converged to the target KL-divergence, yet. To get there would require longer training or starting with a higher initial coefficient.

# %% [markdown]
# ## Model inspection
# Let's inspect some examples from the IMDB dataset. We can use `model_ref` to compare the tuned model `model` against the model before optimisation.

# %%
#### get a batch from the dataset
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /raid/sourab/miniconda3/envs/hf/lib/python3.10/site-packages/transformers/pipelines/base.py:1123: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                           query  \
# 0   When originally screened in America in 1972
# 1                                    Born Again
# 2                           Generally speaking,
# 3                        I have seen the recent
# 4            Description: Corny, utterly stupid
# 5                           Director Edward Sed
# 6                                Robert Siodmak
# 7                                        DO NOT
# 8                          Where to start, this
# 9                                  STAR RATING:
# 10                     I became a fan of the TV
# 11                           This is a very old
# 12                             **SPOILERS** Red
# 13                                     Mirage (
# 14                         Vampire cyborgs rule
# 15                                  Yet another
#
#                                     response (before)  \
# 0                               , this would become a
# 1    is just awful; her only chased after a nun st...
# 2    the British would rather that Britain shone a...
# 3                  improvements of 'Hunter and Madam,
# 4                , absurd, Mel Brooks character -- is
# 5             ol-Smith who was dismayed by this mercy
# 6    plays a group of high school student Valerie ...
# 7                                    BE JUDGEED!!NOTE
# 8    well-done collection could have easily been o...
# 9    8/10 deliverers do not set off alarm bells in...
# 10                                    lead and by the
# 11  , beautiful movie, nice color, vibrant action,...
# 12              **SPOILERS** Redeemable.<|endoftext|>
# 13                                Julio) as an Amazon
# 14   the land, thus to steal from souls of ancesto...
# 15   suggestion is that the film, which is far fro...
#
#                                      response (after)  rewards (before)  \
# 0                                       , this is a &          1.155222
# 1    is a fun ride, confident adventure with Russi...         -2.930447
# 2    I found it interesting and I really enjoyed t...         -0.048785
# 3           movies of the Long City within as much as          1.404229
# 4                , fun and especially good as a mummy         -2.245211
# 5                  law is one of my favorite (dr. one         -1.463929
# 6    is a great actor. The story is fantastic prov...          0.475510
# 7                                SILENTLY READ!! It's          0.281520
# 8    one of the best movies I've ever heard of the...          2.047390
# 9    I love this movie, and the acting. It is trul...          0.642155
# 10                                   shows like this.          1.569069
# 11   thing you know! The story is brilliant, and a...          2.295634
# 12  wings is a very comic and full of intelligent ...         -1.535502
# 13                     a great movie). This brilliant          0.630505
# 14   over the galaxy and that the three alien bein...         -0.671057
# 15   a gorgeous storyline with the early life and ...         -0.553307
#
#     rewards (after)
# 0          1.224865
# 1          2.764369
# 2          2.599930
# 3          1.642995
# 4          1.383026
# 5          2.364105
# 6          2.585483
# 7          0.485400
# 8          2.238423
# 9          2.750093
# 10         1.378879
# 11         2.423416
# 12         2.678708
# 13         2.766769
# 14        -0.817907
# 15         2.784310

# %% [markdown]
# Looking at the reward mean/median of the generated sequences we observe a significant difference.

# %%
print("mean:")
display(df_results[["rewards (before)", "rewards (after)"]].mean())
print()
print("median:")
display(df_results[["rewards (before)", "rewards (after)"]].median())
# Out:
# mean:
# rewards (before)    0.065812
# rewards (after)     1.953304
# dtype: float64
# median:
# rewards (before)    0.378515
# rewards (after)     2.393761
# dtype: float64

# %% [markdown]
# ## Save model
# Finally, we save the model and push it to the Hugging Face for later usage.

# %%
model.save_pretrained("gpt2-imdb-pos-v2", push_to_hub=True)
tokenizer.save_pretrained("gpt2-imdb-pos-v2", push_to_hub=True)
# Out:
# model.safetensors:   0%|          | 0.00/498M [00:00<?, ?B/s]
# ('gpt2-imdb-pos-v2/tokenizer_config.json',
#  'gpt2-imdb-pos-v2/special_tokens_map.json',
#  'gpt2-imdb-pos-v2/vocab.json',
#  'gpt2-imdb-pos-v2/merges.txt',
#  'gpt2-imdb-pos-v2/added_tokens.json',
#  'gpt2-imdb-pos-v2/tokenizer.json')
